# %%
# !git clone https://github.com/danieldev-tech/snake-ai.git
# Out:
# Cloning into 'snake-ai'...
# remote: Enumerating objects: 313, done.
# remote: Counting objects: 100% (167/167), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 313 (delta 126), reused 123 (delta 114), pack-reused 146 (from 1)
# Receiving objects: 100% (313/313), 29.10 MiB | 32.75 MiB/s, done.
# Resolving deltas: 100% (203/203), done.

# %%
pip install stable_baselines3 sb3-contrib pygame gymnasium
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.5/187.5 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 6.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
cd snake-ai/main
# Out:
# /kaggle/working/snake-ai/main

# %%
# !python3 train_cnn.py
# Out:
# 2026-04-21 17:56:13.254545: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776794173.717679      60 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776794173.841787      60 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776794174.841065      60 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
